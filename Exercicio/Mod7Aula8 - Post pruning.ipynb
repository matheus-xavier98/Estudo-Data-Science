# %% [markdown]
# # 0. Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Carregando o dataframe](#read)
# 5. [Dados duplicados](#duplicados)
# 3. [Identificando e Tratando dados ausentes/missing](#identificando)
# 6. [Dados categorizados](#categorizados)
# 6. [Separando as variáveis explicativas da target](#separando)
# 6. [Árvore de classificação com todas as variáveis](#arvore)
# 6. [Separando entre treino e teste](#treino_teste)
# 6. [Post pruning](#post)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # 2. Carregando um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# # 3. Dados duplicados <a name="duplicados"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
titanic.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic = titanic.drop_duplicates()
titanic.shape
# Out:
# (784, 15)

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 885         0       3  female  39.0      0      5  29.125        Q  Third
# 887         1       1  female  19.0      0      0  30.000        S  First
# 888         0       3  female   NaN      1      2  23.450        S  Third
# 889         1       1    male  26.0      0      0  30.000        C  First
# 890         0       3    male  32.0      0      0   7.750        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.reset_index(drop=True, inplace=True)

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 779         0       3  female  39.0      0      5  29.125        Q  Third
# 780         1       1  female  19.0      0      0  30.000        S  First
# 781         0       3  female   NaN      1      2  23.450        S  Third
# 782         1       1    male  26.0      0      0  30.000        C  First
# 783         0       3    male  32.0      0      0   7.750        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True

# %% [markdown]
# # 4. Identificando e tratando dados ausentes <a name="identificando"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %% [markdown]
# https://scikit-learn.org/stable/modules/tree.html#id2
#
#
# A árvore de decisão requer pouca preparação de dados. Outras técnicas geralmente requerem normalização de dados, variáveis fictícias precisam ser criadas e valores em branco precisam ser removidos. Observe, entretanto, que **este módulo não oferece suporte a valores ausentes**.

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
percentage = (titanic.isnull().sum() / len(titanic)) * 100
percentage
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            13.520408
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.255102
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           74.234694
# embark_town     0.255102
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# dropar todas as colunas que tenha pelo menos 1 NA
titanic_sem_na = titanic.dropna(axis=1)

# %%
titanic_sem_na.head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare  class    who  adult_male  \
# 0         0       3    male      1      0   7.2500  Third    man        True
# 1         1       1  female      1      0  71.2833  First  woman       False
# 2         1       3  female      0      0   7.9250  Third  woman       False
# 3         1       1  female      1      0  53.1000  First  woman       False
# 4         0       3    male      0      0   8.0500  Third    man        True
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True
# 3   yes  False
# 4    no   True

# %%
titanic_sem_na.shape
# Out:
# (784, 11)

# %%
titanic_sem_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    784 non-null    int64
#  1   pclass      784 non-null    int64
#  2   sex         784 non-null    object
#  3   sibsp       784 non-null    int64
#  4   parch       784 non-null    int64
#  5   fare        784 non-null    float64
#  6   class       784 non-null    category
#  7   who         784 non-null    object
#  8   adult_male  784 non-null    bool
#  9   alive       784 non-null    object
#  10  alone       784 non-null    bool
# dtypes: bool(2), category(1), float64(1), int64(4), object(3)
# memory usage: 51.6+ KB

# %% [markdown]
# # 5. Dados categorizados <a name="categorizados"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %% [markdown]
# https://scikit-learn.org/stable/modules/tree.html#id2
#
# CART (árvores de classificação e regressão) é muito semelhante a C4.5, mas difere porque oferece suporte a variáveis ​​de destino numéricas (regressão) e não calcula conjuntos de regras. A CART constrói árvores binárias usando o recurso e o limite que geram o maior ganho de informação em cada nó.
#
# scikit-learn usa uma versão otimizada do algoritmo CART; entretanto, a **implementação do scikit-learn não suporta variáveis categorizadas** por enquanto.

# %%
titanic_sem_na.head(2)
# Out:
#    survived  pclass     sex  sibsp  parch     fare  class    who  adult_male  \
# 0         0       3    male      1      0   7.2500  Third    man        True
# 1         1       1  female      1      0  71.2833  First  woman       False
#
#   alive  alone
# 0    no  False
# 1   yes  False

# %% [markdown]
# - **survived** - se o passageiro sobreviveu ou não, ou seja, nossa target
# - **pclass** - classe em que o passageiro estava (primeira, segunda, terceira)
# - **sex** - genero do passageiro (masculino ou feminino)
# - **sibsp** - quantidade de irmãos/esposos/esposas no navio (0 a 8)
# - **parch** - quantidade de pais/filhos a bordo
# - **fare** - preço do ticket
# - **class** - igual a pclass
# - **who** - se é homem, mulher ou criança
# - **adult_male** - se é um homem adulto
# - **alive** - igual a survived
# - **alone** - se estava sozinho a bordo

# %% [markdown]
# ## Survived e alive

# %%
titanic_sem_na.survived.value_counts()
# Out:
# survived
# 0    461
# 1    323
# Name: count, dtype: int64

# %%
titanic_sem_na.survived.value_counts(normalize=True)
# Out:
# survived
# 0    0.58801
# 1    0.41199
# Name: proportion, dtype: float64

# %%
titanic_sem_na.alive.value_counts()
# Out:
# alive
# no     461
# yes    323
# Name: count, dtype: int64

# %%
titanic_sem_na[['alive','survived','sibsp']].groupby(['alive','survived']).count()
# Out:
#                 sibsp
# alive survived
# no    0           461
# yes   1           323

# %%
titanic_sem_na = titanic_sem_na.drop('alive',axis=1)

# %% [markdown]
# ## pclass e class

# %%
titanic_sem_na['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_sem_na['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanic_sem_na[['pclass','class','sibsp']].groupby(['pclass','class']).count()
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_4160\2776273745.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_sem_na[['pclass','class','sibsp']].groupby(['pclass','class']).count()
#                sibsp
# pclass class
# 1      First     214
#        Second      0
#        Third       0
# 2      First       0
#        Second    165
#        Third       0
# 3      First       0
#        Second      0
#        Third     405

# %%
titanic_sem_na = titanic_sem_na.drop('pclass',axis=1)

# %% [markdown]
# ## Outras variáveis

# %%
titanic_sem_na['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_sem_na['sibsp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
titanic_sem_na['parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
titanic_sem_na['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
titanic_sem_na[['sex','who','sibsp']].groupby(['sex','who']).count()
# Out:
#               sibsp
# sex    who
# female child     42
#        woman    251
# male   child     40
#        man      451

# %%
titanic_sem_na.head(2)
# Out:
#    survived     sex  sibsp  parch     fare  class    who  adult_male  alone
# 0         0    male      1      0   7.2500  Third    man        True  False
# 1         1  female      1      0  71.2833  First  woman       False  False

# %% [markdown]
# ## Transformando em dummie (flag)

# %%
# titanic_encoded = titanic_sem_na.copy()
titanic_encoded = pd.get_dummies(titanic_sem_na, columns=['class','who'], drop_first=True)
titanic_encoded.head(20)
# Out:
#     survived     sex  sibsp  parch     fare  adult_male  alone  class_Second  \
# 0          0    male      1      0   7.2500        True  False         False
# 1          1  female      1      0  71.2833       False  False         False
# 2          1  female      0      0   7.9250       False   True         False
# 3          1  female      1      0  53.1000       False  False         False
# 4          0    male      0      0   8.0500        True   True         False
# 5          0    male      0      0   8.4583        True   True         False
# 6          0    male      0      0  51.8625        True   True         False
# 7          0    male      3      1  21.0750       False  False         False
# 8          1  female      0      2  11.1333       False  False         False
# 9          1  female      1      0  30.0708       False  False          True
# 10         1  female      1      1  16.7000       False  False         False
# 11         1  female      0      0  26.5500       False   True         False
# 12         0    male      0      0   8.0500        True   True         False
# 13         0    male      1      5  31.2750        True  False         False
# 14         0  female      0      0   7.8542       False   True         False
# 15         1  female      0      0  16.0000       False   True          True
# 16         0    male      4      1  29.1250       False  False         False
# 17         1    male      0      0  13.0000        True   True          True
# 18         0  female      1      0  18.0000       False  False         False
# 19         1  female      0      0   7.2250       False   True         False
#
#     class_Third  who_man  who_woman
# 0          True     True      False
# 1         False    False       True
# 2          True    False       True
# 3         False    False       True
# 4          True     True      False
# 5          True     True      False
# 6         False     True      False
# 7          True    False      False
# 8          True    False       True
# 9         False    False      False
# 10         True    False      False
# 11        False    False       True
# 12         True     True      False
# 13         True     True      False
# 14         True    False      False
# 15        False    False       True
# 16         True    False      False
# 17        False     True      False
# 18         True    False       True
# 19         True    False       True

# %% [markdown]
# ## Mapping

# %%
titanic_encoded.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_encoded.sex = titanic_encoded.sex.map({'female': 1, 'male':0})

# %%
titanic_encoded.sex.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## Mudando alguns tipos de dados

# %%
titanic_encoded.dtypes
# Out:
# survived          int64
# sex               int64
# sibsp             int64
# parch             int64
# fare            float64
# adult_male         bool
# alone              bool
# class_Second       bool
# class_Third        bool
# who_man            bool
# who_woman          bool
# dtype: object

# %%
titanic_encoded.adult_male.astype(int)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 779    0
# 780    0
# 781    0
# 782    1
# 783    1
# Name: adult_male, Length: 784, dtype: int32

# %%
titanic_encoded.adult_male = titanic_encoded.adult_male.astype(int)
titanic_encoded.alone = titanic_encoded.alone.astype(int)

# %%
titanic_encoded.dtypes
# Out:
# survived          int64
# sex               int64
# sibsp             int64
# parch             int64
# fare            float64
# adult_male        int32
# alone             int32
# class_Second       bool
# class_Third        bool
# who_man            bool
# who_woman          bool
# dtype: object

# %%
titanic_encoded.columns
# Out:
# Index(['survived', 'sex', 'sibsp', 'parch', 'fare', 'adult_male', 'alone',
#        'class_Second', 'class_Third', 'who_man', 'who_woman'],
#       dtype='object')

# %% [markdown]
# # 6. Separando as variáveis explicativas da target <a name="separando"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
y = titanic_encoded.survived

# %%
X = titanic_encoded.drop('survived',axis=1)

# %% [markdown]
# # 7. Árvore de classificação com todas as variáveis <a name="arvore"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
clf_dt = DecisionTreeClassifier(random_state=100)
clf_dt
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
clf_dt = clf_dt.fit(X,y)
clf_dt
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
plt.figure(figsize=(25, 10))
plot_tree(clf_dt,
          filled=True,
          class_names=['Died', 'Survived'],
          feature_names=X.columns)
# Out:
# [Text(0.47796610169491527, 0.9736842105263158, 'who_man <= 0.5\ngini = 0.485\nsamples = 784\nvalue = [461, 323]\nclass = Died'),
#  Text(0.21620762711864408, 0.9210526315789473, 'class_Third <= 0.5\ngini = 0.408\nsamples = 333\nvalue = [95, 238]\nclass = Survived'),
#  Text(0.34708686440677966, 0.9473684210526316, 'True  '),
#  Text(0.10762711864406779, 0.868421052631579, 'fare <= 28.856\ngini = 0.096\nsamples = 178\nvalue = [9, 169]\nclass = Survived'),
#  Text(0.07966101694915254, 0.8157894736842105, 'fare <= 28.231\ngini = 0.176\nsamples = 72\nvalue = [7, 65]\nclass = Survived'),
#  Text(0.07288135593220339, 0.7631578947368421, 'parch <= 0.5\ngini = 0.155\nsamples = 71\nvalue = [6, 65]\nclass = Survived'),
#  Text(0.05084745762711865, 0.7105263157894737, 'alone <= 0.5\ngini = 0.201\nsamples = 44\nvalue = [5, 39]\nclass = Survived'),
#  Text(0.02711864406779661, 0.6578947368421053, 'fare <= 22.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = Survived'),
#  Text(0.013559322033898305, 0.6052631578947368, 'fare <= 17.429\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.006779661016949152, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.020338983050847456, 0.5526315789473685, 'sibsp <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.013559322033898305, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.02711864406779661, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.04067796610169491, 0.6052631578947368, 'fare <= 25.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Survived'),
#  Text(0.03389830508474576, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.04745762711864407, 0.5526315789473685, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.07457627118644068, 0.6578947368421053, 'fare <= 13.25\ngini = 0.165\nsamples = 33\nvalue = [3, 30]\nclass = Survived'),
#  Text(0.06779661016949153, 0.6052631578947368, 'fare <= 12.825\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = Survived'),
#  Text(0.061016949152542375, 0.5526315789473685, 'fare <= 11.25\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Survived'),
#  Text(0.05423728813559322, 0.5, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.06779661016949153, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.07457627118644068, 0.5526315789473685, 'gini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Survived'),
#  Text(0.08135593220338982, 0.6052631578947368, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.09491525423728814, 0.7105263157894737, 'sibsp <= 0.5\ngini = 0.071\nsamples = 27\nvalue = [1, 26]\nclass = Survived'),
#  Text(0.08813559322033898, 0.6578947368421053, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Survived'),
#  Text(0.1016949152542373, 0.6578947368421053, 'who_woman <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = Survived'),
#  Text(0.09491525423728814, 0.6052631578947368, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Survived'),
#  Text(0.10847457627118644, 0.6052631578947368, 'fare <= 26.125\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.1016949152542373, 0.5526315789473685, 'parch <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.09491525423728814, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.10847457627118644, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.1152542372881356, 0.5526315789473685, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.08644067796610169, 0.7631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.13559322033898305, 0.8157894736842105, 'fare <= 149.035\ngini = 0.037\nsamples = 106\nvalue = [2, 104]\nclass = Survived'),
#  Text(0.1288135593220339, 0.7631578947368421, 'gini = 0.0\nsamples = 86\nvalue = [0, 86]\nclass = Survived'),
#  Text(0.1423728813559322, 0.7631578947368421, 'fare <= 152.506\ngini = 0.18\nsamples = 20\nvalue = [2, 18]\nclass = Survived'),
#  Text(0.13559322033898305, 0.7105263157894737, 'alone <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.1288135593220339, 0.6578947368421053, 'sex <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.12203389830508475, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.13559322033898305, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.1423728813559322, 0.6578947368421053, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.14915254237288136, 0.7105263157894737, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Survived'),
#  Text(0.32478813559322034, 0.868421052631579, 'fare <= 23.35\ngini = 0.494\nsamples = 155\nvalue = [86, 69]\nclass = Died'),
#  Text(0.24279661016949153, 0.8157894736842105, 'who_woman <= 0.5\ngini = 0.491\nsamples = 115\nvalue = [50, 65]\nclass = Survived'),
#  Text(0.18305084745762712, 0.7631578947368421, 'sibsp <= 2.5\ngini = 0.412\nsamples = 31\nvalue = [9, 22]\nclass = Survived'),
#  Text(0.17627118644067796, 0.7105263157894737, 'fare <= 10.798\ngini = 0.337\nsamples = 28\nvalue = [6, 22]\nclass = Survived'),
#  Text(0.15593220338983052, 0.6578947368421053, 'fare <= 9.49\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.14915254237288136, 0.6052631578947368, 'sibsp <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.1423728813559322, 0.5526315789473685, 'fare <= 7.542\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.13559322033898305, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.14915254237288136, 0.5, 'fare <= 7.942\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.1423728813559322, 0.4473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.15593220338983052, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.15593220338983052, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.16271186440677965, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.19661016949152543, 0.6578947368421053, 'parch <= 0.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]\nclass = Survived'),
#  Text(0.17627118644067796, 0.6052631578947368, 'fare <= 13.465\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.1694915254237288, 0.5526315789473685, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.18305084745762712, 0.5526315789473685, 'fare <= 16.621\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.17627118644067796, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.18983050847457628, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.21694915254237288, 0.6052631578947368, 'fare <= 15.494\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = Survived'),
#  Text(0.21016949152542372, 0.5526315789473685, 'fare <= 14.331\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Survived'),
#  Text(0.2033898305084746, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.21694915254237288, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.22372881355932203, 0.5526315789473685, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.18983050847457628, 0.7105263157894737, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.30254237288135594, 0.7631578947368421, 'fare <= 7.888\ngini = 0.5\nsamples = 84\nvalue = [41, 43]\nclass = Survived'),
#  Text(0.2440677966101695, 0.7105263157894737, 'parch <= 1.0\ngini = 0.458\nsamples = 31\nvalue = [11, 20]\nclass = Survived'),
#  Text(0.23728813559322035, 0.6578947368421053, 'fare <= 6.987\ngini = 0.444\nsamples = 30\nvalue = [10, 20]\nclass = Survived'),
#  Text(0.2305084745762712, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.2440677966101695, 0.6052631578947368, 'fare <= 7.523\ngini = 0.428\nsamples = 29\nvalue = [9, 20]\nclass = Survived'),
#  Text(0.23728813559322035, 0.5526315789473685, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.25084745762711863, 0.5526315789473685, 'fare <= 7.781\ngini = 0.461\nsamples = 25\nvalue = [9, 16]\nclass = Survived'),
#  Text(0.23389830508474577, 0.5, 'fare <= 7.744\ngini = 0.494\nsamples = 18\nvalue = [8, 10]\nclass = Survived'),
#  Text(0.22033898305084745, 0.4473684210526316, 'fare <= 7.64\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Survived'),
#  Text(0.2135593220338983, 0.39473684210526316, 'fare <= 7.59\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.20677966101694914, 0.34210526315789475, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.22033898305084745, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.2271186440677966, 0.39473684210526316, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.24745762711864408, 0.4473684210526316, 'fare <= 7.763\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.24067796610169492, 0.39473684210526316, 'gini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = Died'),
#  Text(0.2542372881355932, 0.39473684210526316, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.2677966101694915, 0.5, 'fare <= 7.842\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.26101694915254237, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.2745762711864407, 0.4473684210526316, 'fare <= 7.867\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.2677966101694915, 0.39473684210526316, 'sibsp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.26101694915254237, 0.34210526315789475, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.2745762711864407, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.28135593220338984, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.25084745762711863, 0.6578947368421053, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.3610169491525424, 0.7105263157894737, 'fare <= 14.873\ngini = 0.491\nsamples = 53\nvalue = [30, 23]\nclass = Died'),
#  Text(0.33559322033898303, 0.6578947368421053, 'parch <= 1.5\ngini = 0.43\nsamples = 32\nvalue = [22, 10]\nclass = Died'),
#  Text(0.3288135593220339, 0.6052631578947368, 'sibsp <= 0.5\ngini = 0.391\nsamples = 30\nvalue = [22, 8]\nclass = Died'),
#  Text(0.3220338983050847, 0.5526315789473685, 'fare <= 13.465\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = Died'),
#  Text(0.3152542372881356, 0.5, 'parch <= 0.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = Died'),
#  Text(0.30847457627118646, 0.4473684210526316, 'fare <= 11.496\ngini = 0.469\nsamples = 16\nvalue = [10, 6]\nclass = Died'),
#  Text(0.3016949152542373, 0.39473684210526316, 'fare <= 7.988\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = Died'),
#  Text(0.288135593220339, 0.34210526315789475, 'fare <= 7.91\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.28135593220338984, 0.2894736842105263, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.29491525423728815, 0.2894736842105263, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.3152542372881356, 0.34210526315789475, 'fare <= 8.673\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Died'),
#  Text(0.30847457627118646, 0.2894736842105263, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.3220338983050847, 0.2894736842105263, 'fare <= 8.767\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Died'),
#  Text(0.3152542372881356, 0.23684210526315788, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3288135593220339, 0.23684210526315788, 'fare <= 9.219\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Died'),
#  Text(0.3220338983050847, 0.18421052631578946, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.33559322033898303, 0.18421052631578946, 'fare <= 10.179\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.3288135593220339, 0.13157894736842105, 'fare <= 9.84\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.3220338983050847, 0.07894736842105263, 'fare <= 9.712\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.3152542372881356, 0.02631578947368421, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.3288135593220339, 0.02631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.33559322033898303, 0.07894736842105263, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3423728813559322, 0.13157894736842105, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.3152542372881356, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3220338983050847, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3288135593220339, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.33559322033898303, 0.5526315789473685, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Died'),
#  Text(0.3423728813559322, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3864406779661017, 0.6578947368421053, 'fare <= 21.717\ngini = 0.472\nsamples = 21\nvalue = [8, 13]\nclass = Survived'),
#  Text(0.37966101694915255, 0.6052631578947368, 'fare <= 17.6\ngini = 0.494\nsamples = 18\nvalue = [8, 10]\nclass = Survived'),
#  Text(0.3559322033898305, 0.5526315789473685, 'parch <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.3423728813559322, 0.5, 'fare <= 15.975\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Survived'),
#  Text(0.33559322033898303, 0.4473684210526316, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.34915254237288135, 0.4473684210526316, 'fare <= 16.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.3423728813559322, 0.39473684210526316, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.3559322033898305, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3694915254237288, 0.5, 'parch <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.36271186440677966, 0.4473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.376271186440678, 0.4473684210526316, 'fare <= 15.973\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.3694915254237288, 0.39473684210526316, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.38305084745762713, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4033898305084746, 0.5526315789473685, 'fare <= 18.629\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Died'),
#  Text(0.39661016949152544, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.4101694915254237, 0.5, 'sibsp <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.4033898305084746, 0.4473684210526316, 'fare <= 19.735\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.39661016949152544, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4101694915254237, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.41694915254237286, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.39322033898305087, 0.6052631578947368, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.4067796610169492, 0.8157894736842105, 'parch <= 0.5\ngini = 0.18\nsamples = 40\nvalue = [36, 4]\nclass = Died'),
#  Text(0.4, 0.7631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4135593220338983, 0.7631578947368421, 'fare <= 31.331\ngini = 0.142\nsamples = 39\nvalue = [36, 3]\nclass = Died'),
#  Text(0.4067796610169492, 0.7105263157894737, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Died'),
#  Text(0.42033898305084744, 0.7105263157894737, 'fare <= 32.881\ngini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = Died'),
#  Text(0.4135593220338983, 0.6578947368421053, 'sex <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.4067796610169492, 0.6052631578947368, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.42033898305084744, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4271186440677966, 0.6578947368421053, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.7397245762711865, 0.9210526315789473, 'fare <= 26.269\ngini = 0.306\nsamples = 451\nvalue = [366, 85]\nclass = Died'),
#  Text(0.6088453389830508, 0.9473684210526316, '  False'),
#  Text(0.6247881355932203, 0.868421052631579, 'fare <= 23.35\ngini = 0.219\nsamples = 319\nvalue = [279.0, 40.0]\nclass = Died'),
#  Text(0.5597457627118644, 0.8157894736842105, 'fare <= 22.887\ngini = 0.231\nsamples = 292\nvalue = [253, 39]\nclass = Died'),
#  Text(0.5529661016949152, 0.7631578947368421, 'fare <= 7.746\ngini = 0.227\nsamples = 291\nvalue = [253, 38]\nclass = Died'),
#  Text(0.4711864406779661, 0.7105263157894737, 'fare <= 7.24\ngini = 0.149\nsamples = 74\nvalue = [68, 6]\nclass = Died'),
#  Text(0.46440677966101696, 0.6578947368421053, 'fare <= 7.133\ngini = 0.211\nsamples = 50\nvalue = [44, 6]\nclass = Died'),
#  Text(0.45084745762711864, 0.6052631578947368, 'fare <= 7.01\ngini = 0.108\nsamples = 35\nvalue = [33, 2]\nclass = Died'),
#  Text(0.4440677966101695, 0.5526315789473685, 'fare <= 6.962\ngini = 0.165\nsamples = 22\nvalue = [20, 2]\nclass = Died'),
#  Text(0.43728813559322033, 0.5, 'fare <= 2.006\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Died'),
#  Text(0.43050847457627117, 0.4473684210526316, 'class_Third <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Died'),
#  Text(0.423728813559322, 0.39473684210526316, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Died'),
#  Text(0.43728813559322033, 0.39473684210526316, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.4440677966101695, 0.4473684210526316, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Died'),
#  Text(0.45084745762711864, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.4576271186440678, 0.5526315789473685, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Died'),
#  Text(0.47796610169491527, 0.6052631578947368, 'fare <= 7.183\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Died'),
#  Text(0.4711864406779661, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4847457627118644, 0.5526315789473685, 'parch <= 0.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]\nclass = Died'),
#  Text(0.47796610169491527, 0.5, 'fare <= 7.227\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = Died'),
#  Text(0.4711864406779661, 0.4473684210526316, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.4847457627118644, 0.4473684210526316, 'gini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Died'),
#  Text(0.4915254237288136, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.47796610169491527, 0.6578947368421053, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Died'),
#  Text(0.6347457627118644, 0.7105263157894737, 'fare <= 8.135\ngini = 0.251\nsamples = 217\nvalue = [185, 32]\nclass = Died'),
#  Text(0.5864406779661017, 0.6578947368421053, 'fare <= 7.91\ngini = 0.313\nsamples = 98\nvalue = [79, 19]\nclass = Died'),
#  Text(0.5457627118644067, 0.6052631578947368, 'fare <= 7.798\ngini = 0.225\nsamples = 62\nvalue = [54, 8]\nclass = Died'),
#  Text(0.5186440677966102, 0.5526315789473685, 'fare <= 7.785\ngini = 0.312\nsamples = 31\nvalue = [25, 6]\nclass = Died'),
#  Text(0.511864406779661, 0.5, 'sibsp <= 0.5\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = Died'),
#  Text(0.49830508474576274, 0.4473684210526316, 'fare <= 7.763\ngini = 0.236\nsamples = 22\nvalue = [19, 3]\nclass = Died'),
#  Text(0.4915254237288136, 0.39473684210526316, 'gini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Died'),
#  Text(0.5050847457627119, 0.39473684210526316, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Died'),
#  Text(0.5254237288135594, 0.4473684210526316, 'fare <= 7.763\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.5186440677966102, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5322033898305085, 0.39473684210526316, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.5254237288135594, 0.5, 'gini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Died'),
#  Text(0.5728813559322034, 0.5526315789473685, 'fare <= 7.865\ngini = 0.121\nsamples = 31\nvalue = [29, 2]\nclass = Died'),
#  Text(0.559322033898305, 0.5, 'sibsp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Died'),
#  Text(0.5525423728813559, 0.4473684210526316, 'fare <= 7.842\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.5457627118644067, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.559322033898305, 0.39473684210526316, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.5661016949152542, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5864406779661017, 0.5, 'fare <= 7.892\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Died'),
#  Text(0.5796610169491525, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5932203389830508, 0.4473684210526316, 'gini = 0.1\nsamples = 19\nvalue = [18, 1]\nclass = Died'),
#  Text(0.6271186440677966, 0.6052631578947368, 'fare <= 8.081\ngini = 0.424\nsamples = 36\nvalue = [25, 11]\nclass = Died'),
#  Text(0.6203389830508474, 0.5526315789473685, 'fare <= 7.988\ngini = 0.408\nsamples = 35\nvalue = [25, 10]\nclass = Died'),
#  Text(0.6135593220338983, 0.5, 'sibsp <= 1.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.6067796610169491, 0.4473684210526316, 'alone <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]\nclass = Survived'),
#  Text(0.6, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6135593220338983, 0.39473684210526316, 'gini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = Died'),
#  Text(0.6203389830508474, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6271186440677966, 0.5, 'gini = 0.33\nsamples = 24\nvalue = [19, 5]\nclass = Died'),
#  Text(0.6338983050847458, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6830508474576271, 0.6578947368421053, 'fare <= 9.492\ngini = 0.195\nsamples = 119\nvalue = [106, 13]\nclass = Died'),
#  Text(0.6542372881355932, 0.6052631578947368, 'fare <= 8.688\ngini = 0.08\nsamples = 24\nvalue = [23, 1]\nclass = Died'),
#  Text(0.6474576271186441, 0.5526315789473685, 'fare <= 8.658\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Died'),
#  Text(0.6406779661016949, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.6542372881355932, 0.5, 'alone <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Died'),
#  Text(0.6474576271186441, 0.4473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6610169491525424, 0.4473684210526316, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.6610169491525424, 0.5526315789473685, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Died'),
#  Text(0.711864406779661, 0.6052631578947368, 'fare <= 13.931\ngini = 0.221\nsamples = 95\nvalue = [83, 12]\nclass = Died'),
#  Text(0.688135593220339, 0.5526315789473685, 'fare <= 13.681\ngini = 0.27\nsamples = 56\nvalue = [47, 9]\nclass = Died'),
#  Text(0.6813559322033899, 0.5, 'fare <= 9.673\ngini = 0.249\nsamples = 55\nvalue = [47, 8]\nclass = Died'),
#  Text(0.6745762711864407, 0.4473684210526316, 'gini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Died'),
#  Text(0.688135593220339, 0.4473684210526316, 'fare <= 12.938\ngini = 0.223\nsamples = 47\nvalue = [41.0, 6.0]\nclass = Died'),
#  Text(0.6745762711864407, 0.39473684210526316, 'fare <= 11.0\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = Died'),
#  Text(0.6677966101694915, 0.34210526315789475, 'class_Second <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Died'),
#  Text(0.6610169491525424, 0.2894736842105263, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6745762711864407, 0.2894736842105263, 'gini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = Died'),
#  Text(0.6813559322033899, 0.34210526315789475, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.7016949152542373, 0.39473684210526316, 'fare <= 13.25\ngini = 0.298\nsamples = 22\nvalue = [18, 4]\nclass = Died'),
#  Text(0.6949152542372882, 0.34210526315789475, 'gini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Died'),
#  Text(0.7084745762711865, 0.34210526315789475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.6949152542372882, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.735593220338983, 0.5526315789473685, 'parch <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]\nclass = Died'),
#  Text(0.7152542372881356, 0.5, 'fare <= 18.394\ngini = 0.067\nsamples = 29\nvalue = [28, 1]\nclass = Died'),
#  Text(0.7084745762711865, 0.4473684210526316, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Died'),
#  Text(0.7220338983050848, 0.4473684210526316, 'fare <= 19.377\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.7152542372881356, 0.39473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7288135593220338, 0.39473684210526316, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.7559322033898305, 0.5, 'fare <= 15.921\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Died'),
#  Text(0.7491525423728813, 0.4473684210526316, 'fare <= 14.873\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.7423728813559322, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7559322033898305, 0.39473684210526316, 'fare <= 15.373\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7491525423728813, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7627118644067796, 0.34210526315789475, 'fare <= 15.621\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7559322033898305, 0.2894736842105263, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7694915254237288, 0.2894736842105263, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7627118644067796, 0.4473684210526316, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.5665254237288135, 0.7631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6898305084745763, 0.8157894736842105, 'sibsp <= 0.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]\nclass = Died'),
#  Text(0.6830508474576271, 0.7631578947368421, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Died'),
#  Text(0.6966101694915254, 0.7631578947368421, 'fare <= 25.733\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Died'),
#  Text(0.6898305084745763, 0.7105263157894737, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Died'),
#  Text(0.7033898305084746, 0.7105263157894737, 'fare <= 26.125\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.6966101694915254, 0.6578947368421053, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.7101694915254237, 0.6578947368421053, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8546610169491525, 0.868421052631579, 'class_Second <= 0.5\ngini = 0.449\nsamples = 132\nvalue = [87, 45]\nclass = Died'),
#  Text(0.8478813559322034, 0.8157894736842105, 'fare <= 26.469\ngini = 0.472\nsamples = 118\nvalue = [73, 45]\nclass = Died'),
#  Text(0.8411016949152542, 0.7631578947368421, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.8546610169491525, 0.7631578947368421, 'fare <= 387.665\ngini = 0.461\nsamples = 114\nvalue = [73, 41]\nclass = Died'),
#  Text(0.8478813559322034, 0.7105263157894737, 'fare <= 134.642\ngini = 0.454\nsamples = 112\nvalue = [73, 39]\nclass = Died'),
#  Text(0.8411016949152542, 0.6578947368421053, 'fare <= 116.638\ngini = 0.469\nsamples = 104\nvalue = [65, 39]\nclass = Died'),
#  Text(0.8343220338983051, 0.6052631578947368, 'fare <= 30.598\ngini = 0.462\nsamples = 102\nvalue = [65, 37]\nclass = Died'),
#  Text(0.7966101694915254, 0.5526315789473685, 'fare <= 29.85\ngini = 0.499\nsamples = 31\nvalue = [16, 15]\nclass = Died'),
#  Text(0.7830508474576271, 0.5, 'fare <= 27.135\ngini = 0.463\nsamples = 22\nvalue = [14, 8]\nclass = Died'),
#  Text(0.7762711864406779, 0.4473684210526316, 'gini = 0.5\nsamples = 14\nvalue = [7, 7]\nclass = Died'),
#  Text(0.7898305084745763, 0.4473684210526316, 'fare <= 29.1\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.7830508474576271, 0.39473684210526316, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.7966101694915254, 0.39473684210526316, 'parch <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.7898305084745763, 0.34210526315789475, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8033898305084746, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8101694915254237, 0.5, 'fare <= 30.25\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Survived'),
#  Text(0.8033898305084746, 0.4473684210526316, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.8169491525423729, 0.4473684210526316, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.8720338983050847, 0.5526315789473685, 'fare <= 52.277\ngini = 0.428\nsamples = 71\nvalue = [49, 22]\nclass = Died'),
#  Text(0.8440677966101695, 0.5, 'fare <= 37.0\ngini = 0.278\nsamples = 30\nvalue = [25, 5]\nclass = Died'),
#  Text(0.8305084745762712, 0.4473684210526316, 'fare <= 35.25\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Died'),
#  Text(0.823728813559322, 0.39473684210526316, 'fare <= 31.137\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Died'),
#  Text(0.8169491525423729, 0.34210526315789475, 'fare <= 30.848\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.8101694915254237, 0.2894736842105263, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.823728813559322, 0.2894736842105263, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8305084745762712, 0.34210526315789475, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.8372881355932204, 0.39473684210526316, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.8576271186440678, 0.4473684210526316, 'alone <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Died'),
#  Text(0.8508474576271187, 0.39473684210526316, 'fare <= 45.844\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.8440677966101695, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8576271186440678, 0.34210526315789475, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.864406779661017, 0.39473684210526316, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Died'),
#  Text(0.9, 0.5, 'fare <= 59.087\ngini = 0.485\nsamples = 41\nvalue = [24, 17]\nclass = Died'),
#  Text(0.8847457627118644, 0.4473684210526316, 'fare <= 52.827\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = Survived'),
#  Text(0.8779661016949153, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8915254237288136, 0.39473684210526316, 'fare <= 56.712\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = Survived'),
#  Text(0.8847457627118644, 0.34210526315789475, 'fare <= 54.271\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = Died'),
#  Text(0.8779661016949153, 0.2894736842105263, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.8915254237288136, 0.2894736842105263, 'fare <= 55.671\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.8847457627118644, 0.23684210526315788, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8983050847457628, 0.23684210526315788, 'sibsp <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Died'),
#  Text(0.8915254237288136, 0.18421052631578946, 'gini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.9050847457627119, 0.18421052631578946, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8983050847457628, 0.34210526315789475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9152542372881356, 0.4473684210526316, 'fare <= 62.669\ngini = 0.417\nsamples = 27\nvalue = [19, 8]\nclass = Died'),
#  Text(0.9084745762711864, 0.39473684210526316, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.9220338983050848, 0.39473684210526316, 'fare <= 64.979\ngini = 0.444\nsamples = 24\nvalue = [16, 8]\nclass = Died'),
#  Text(0.9152542372881356, 0.34210526315789475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9288135593220339, 0.34210526315789475, 'fare <= 73.865\ngini = 0.423\nsamples = 23\nvalue = [16, 7]\nclass = Died'),
#  Text(0.9220338983050848, 0.2894736842105263, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.9355932203389831, 0.2894736842105263, 'fare <= 77.008\ngini = 0.455\nsamples = 20\nvalue = [13, 7]\nclass = Died'),
#  Text(0.9288135593220339, 0.23684210526315788, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9423728813559322, 0.23684210526315788, 'fare <= 86.29\ngini = 0.401\nsamples = 18\nvalue = [13, 5]\nclass = Died'),
#  Text(0.9186440677966101, 0.18421052631578946, 'parch <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Died'),
#  Text(0.911864406779661, 0.13157894736842105, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.9254237288135593, 0.13157894736842105, 'fare <= 78.244\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.9186440677966101, 0.07894736842105263, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.9322033898305084, 0.07894736842105263, 'fare <= 79.425\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.9254237288135593, 0.02631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9389830508474576, 0.02631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.9661016949152542, 0.18421052631578946, 'fare <= 98.752\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = Died'),
#  Text(0.9525423728813559, 0.13157894736842105, 'sibsp <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.9457627118644067, 0.07894736842105263, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.9593220338983051, 0.07894736842105263, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.9796610169491525, 0.13157894736842105, 'parch <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.9728813559322034, 0.07894736842105263, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.9864406779661017, 0.07894736842105263, 'fare <= 112.079\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.9796610169491525, 0.02631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9932203389830508, 0.02631578947368421, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8478813559322034, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8546610169491525, 0.6578947368421053, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Died'),
#  Text(0.8614406779661017, 0.7105263157894737, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8614406779661017, 0.8157894736842105, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Died')]

# %%
predict = clf_dt.predict(X)

# %%
accuracy_score(y, predict)
# Out:
# 0.9170918367346939

# %% [markdown]
# # 8. Separando entre treino e teste <a name="treino_teste"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
clf = DecisionTreeClassifier(random_state=100)
clf = clf.fit(X_train,y_train)

# %%
cm = confusion_matrix(y_test, clf.predict(X_test), labels=clf.classes_)
MatrizDeConfusao = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Died', 'Survived'])

MatrizDeConfusao.plot();

# %% [markdown]
# # 9. Post pruning <a name="post"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html

# %%
clf = DecisionTreeClassifier(random_state=100)
path = clf.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)

# %%
train_scores = [clf.score(X_train, y_train) for clf in clfs]
test_scores = [clf.score(X_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("Acurácia")
ax.set_title("Acurácia x alpha do conjunto de dados de treino e teste")
ax.plot(ccp_alphas, train_scores, marker='o', label="treino",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="teste",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
pd.DataFrame({'alpha': ccp_alphas.tolist(), 'score': test_scores})
# Out:
#        alpha     score
# 0   0.000000  0.762712
# 1   0.000028  0.762712
# 2   0.000065  0.762712
# 3   0.000065  0.762712
# 4   0.000115  0.762712
# 5   0.000122  0.758475
# 6   0.000122  0.758475
# 7   0.000122  0.758475
# 8   0.000142  0.758475
# 9   0.000162  0.758475
# 10  0.000304  0.758475
# 11  0.000312  0.758475
# 12  0.000391  0.758475
# 13  0.000391  0.758475
# 14  0.000406  0.758475
# 15  0.000406  0.758475
# 16  0.000442  0.758475
# 17  0.000521  0.758475
# 18  0.000542  0.758475
# 19  0.000608  0.754237
# 20  0.000608  0.754237
# 21  0.000760  0.754237
# 22  0.000870  0.766949
# 23  0.000900  0.766949
# 24  0.000938  0.766949
# 25  0.000973  0.783898
# 26  0.001014  0.783898
# 27  0.001043  0.775424
# 28  0.001081  0.775424
# 29  0.001123  0.779661
# 30  0.001303  0.779661
# 31  0.001369  0.779661
# 32  0.001453  0.792373
# 33  0.001578  0.788136
# 34  0.001612  0.792373
# 35  0.001668  0.792373
# 36  0.001717  0.788136
# 37  0.001745  0.783898
# 38  0.001770  0.783898
# 39  0.001807  0.783898
# 40  0.001811  0.783898
# 41  0.001862  0.783898
# 42  0.002032  0.779661
# 43  0.002831  0.779661
# 44  0.003244  0.779661
# 45  0.003285  0.779661
# 46  0.003973  0.792373
# 47  0.003985  0.754237
# 48  0.004212  0.754237
# 49  0.009252  0.762712
# 50  0.022588  0.792373
# 51  0.042752  0.720339
# 52  0.160365  0.610169

# %%
clf_podada = DecisionTreeClassifier(random_state=100, ccp_alpha=0.022588)

# %%
clf_podada.fit(X_train, y_train)
predict = clf_podada.predict(X_test)
plot_confusion_matrix(clf_podada, X_test, y_test, display_labels=['Died', 'Survived']);
accuracy_score(y_test, predict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 4
#       2 predict = clf_podada.predict(X_test)
#       3 MatrizDeConfusao = ConfusionMatrixDisplay(confusion_matrix=clf_podada, display_labels=['Died', 'Survived'])
# ----> 4 MatrizDeConfusao.plot()
#
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:141, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     138     fig = ax.figure
#     140 cm = self.confusion_matrix
# --> 141 n_classes = cm.shape[0]
#     143 default_im_kw = dict(interpolation="nearest", cmap=cmap)
#     144 im_kw = im_kw or {}
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'shape'

# %%
pred = clf_podada.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.7923728813559322

# %%
plt.figure(figsize=[10,10])
plot_tree(clf_podada,
         filled=True,
         rounded=True,
         class_names=['Died', 'Survived'],
         feature_names=X_train.columns);

# %%
plt.figure(figsize=(25, 10))
plot_tree(clf_dt,
          filled=True,
          class_names=['Died', 'Survived'],
          feature_names=X.columns);
